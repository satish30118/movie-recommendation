# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/imdb-100000-moviestvshows/contentDataGenre.csv
# /kaggle/input/imdb-100000-moviestvshows/contentDataRegion.csv
# /kaggle/input/imdb-100000-moviestvshows/contentDataPrime.csv

# %% [markdown]
# We have already maked the mood classification model, now there comes the second part , where we have to made the mood based recommendation system, now this dataset have  10000 movies and Tv series , we dont need such a huge ampunt of movies, because e are making a movie recommendation system , where I will show top 10 movies according to refresh the mood of the user. We have to select the best movies/Tv_shows from the daatset , proper data analysis is required for that. Lets do it.

# %%
df1=pd.read_csv("/kaggle/input/imdb-100000-moviestvshows/contentDataGenre.csv")
df2=pd.read_csv("/kaggle/input/imdb-100000-moviestvshows/contentDataPrime.csv")
df3=pd.read_csv("/kaggle/input/imdb-100000-moviestvshows/contentDataRegion.csv")

# %%
df1.head(1)# genres dataset
# Out:
#    dataId  genre
# 0  102795  Drama

# %%
df_dup1 = df1.duplicated('dataId', keep = False)
df_dup1.value_counts()
# Out:
# True     191655
# False     27558
# Name: count, dtype: int64

# %%
# Delete duplicates from dataset 1
df1 = df1.drop_duplicates(subset='dataId')

# %%
(df1["genre"].value_counts()).shape # total no of genres
# Out:
# (28,)

# %%
import matplotlib.pyplot as plt
genre_counts = df1["genre"].value_counts()
plt.bar(genre_counts.index, genre_counts.values)
plt.xlabel("Genre")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.title("Genre Distribution")
plt.show()

# %% [markdown]
# **Data Analysis:**
# From this graph we can say that top 5 genres are Drama, Comedy, Romance, Action, Crime. But it includes both movies and Tv shows. So we should do individual plots for the Tv shows and movies which we will do in the df2 dataset.

# %%
df2.head(1)
# Out:
#    dataId contentType          title length  releaseYear  endYear  votes  \
# 0  102795       movie  Ratha Kanneer    154         1954       -1    349
#
#    rating  gross certificate  \
# 0     8.5     -1         NaN
#
#                                          description
# 0  The story revolves around Mohanasundaram, a re...

# %%
df_dup1 = df2.duplicated('dataId', keep = False)
df_dup1.value_counts()
# Out:
# False    101602
# True          4
# Name: count, dtype: int64

# %%
df2 = df2.drop_duplicates(subset ='dataId')

# %%
df2["gross"].value_counts()
# Out:
# gross
# -1            86955
#  10000          660
#  20000          434
#  0              418
#  30000          329
#               ...
#  36430000         1
#  105490000        1
#  75850000         1
#  60090000         1
#  144800000        1
# Name: count, Length: 4545, dtype: int64

# %% [markdown]
# gross -->
# 1. Basically depends on the how much users see the movie, it is not going to help us at any cost.
# 2. Also contains lots of missing values. I am going to drop it.

# %%
df2["endYear"].value_counts()
# Out:
# endYear
# -1       91335
#  2019      492
#  2022      453
#  2017      451
#  2018      448
#          ...
#  1955       13
#  2024       10
#  1953        7
#  1954        6
#  1952        1
# Name: count, Length: 74, dtype: int64

# %%
df2.drop(["endYear","gross"], axis=1, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101604 entries, 0 to 101604
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dataId       101604 non-null  int64
#  1   contentType  101604 non-null  object
#  2   title        101604 non-null  object
#  3   length       101604 non-null  object
#  4   releaseYear  101604 non-null  int64
#  5   votes        101604 non-null  int64
#  6   rating       101604 non-null  float64
#  7   certificate  58356 non-null   object
#  8   description  101604 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 7.8+ MB

# %% [markdown]
# I will drop the certificate column , as it contains many missing values and also in general user don't think about the certification of the movie before watching. Before droping this column , lets see the certificate column values.

# %%
df2['certificate'].value_counts()
# Out:
# certificate
# Not Rated    12919
# R            12263
# TV-14         5212
# TV-MA         4471
# PG-13         4426
# PG            3779
# Approved      3450
# TV-PG         3173
# Unrated       1947
# Passed        1939
# TV-G          1789
# G             1060
# TV-Y7          783
# TV-Y           587
# GP             132
# TV-Y7-FV       130
# X               77
# M               71
# NC-17           47
# M/PG            35
# 16+             18
# TV-13           12
# 13+              7
# F                5
# AO               5
# MA-17            4
# E                3
# E10+             3
# 12               3
# Open             3
# 18+              2
# 18               1
# T                1
# EM               1
# Name: count, dtype: int64

# %%
import plotly.express as px

# Assuming df is your DataFrame
fig = px.scatter(df2, x='votes', y='rating', color='certificate',
                 title='Scatter Plot of Rating vs. Public Votes by Certificate',
                 labels={'votes': 'Votes', 'rating': 'Rating', 'certificate': 'Certificate'},
                 )

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="b2c147a7-beb6-4dcc-adfb-1336f31b2da5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2c147a7-beb6-4dcc-adfb-1336f31b2da5")) {                    Plotly.newPlot(                        "b2c147a7-beb6-4dcc-adfb-1336f31b2da5",                        [{"hovertemplate":"Certificate=Not Rated\u003cbr\u003eVotes=%{x}\u003cbr\u003eRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not Rated","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Not Rated","showlegend":true,"x":[349,349,349,349,349,349,349,349,349,349,349,349,349,349,349,349,348,348,348,348,348,348,348,348,348,348,348,348,348,347,347,347,347,347,347,347,347,347,347,347,347,347,347,347,347,347,346,346,346,346,346,346,346,346,346,346,346,346,345,345,345,345,345,354,354,354,354,354,354,354,354,354,353,353,353,353,353,353,353,353,353,353,353,353,352,352,352,352,352,352,352,352,352,352,352,352,352,351,351,351,351,351,351,351,351,351,351,351,351,351,351,351,351,351,350,350,350,350,350,350,350,350,350,350,350,350,350,350,350,350,350,349,349,359,359,359,359,359,359,359,359,359,359,359,359,359,359,359,359,359,359,358,358,358,358,358,358,358,358,358,358,358,358,358,358,357,357,357,357,357,357,357,357,357,357,357,357,357,357,357,357,357,357,356,356,356,356,356,356,356,356,356,356,356,356,356,356,356,356,356,356,356,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,355,354,364,364,364,364,364,364,364,364,363,363,363,363,363,363,363,363,363,363,363,363,363,363,363,363,363,363,362,362,362,362,362,362,362,362,362,362,362,362,362,362,362,362,361,361,361,361,361,361,361,361,361,361,361,361,361,361,361,361,361,360,360,360,360,360,360,360,360,360,360,360,360,360,360,360,359,359,359,369,369,369,369,369,369,369,369,369,369,369,369,368,368,368,368,368,368,368,368,368,368,368,368,368,367,367,367,367,367,367,367,366,366,366,366,366,366,366,366,366,366,366,366,366,366,366,366,366,366,365,365,365,365,365,365,365,365,365,365,365,364,364,374,374,374,374,374,374,373,373,373,373,373,373,373,373,373,373,373,373,373,372,372,372,372,372,372,372,372,372,372,371,371,371,371,371,371,371,371,371,371,371,371,371,371,371,371,371,371,371,370,370,370,370,370,370,370,370,370,370,370,370,370,370,370,369,369,369,369,369,369,380,379,379,379,379,379,379,379,379,379,379,379,379,379,379,378,378,378,378,378,378,378,378,378,378,378,378,378,378,377,377,377,377,377,377,377,377,377,377,377,377,377,377,377,377,377,376,376,376,376,376,376,376,376,376,376,376,376,376,376,376,376,375,375,375,375,375,375,375,375,375,375,374,374,374,374,374,374,374,374,385,385,385,384,384,384,384,384,384,384,384,384,384,384,384,384,384,384,384,383,383,383,383,383,383,383,383,383,383,383,383,383,383,383,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,382,381,381,381,381,381,381,381,381,381,381,381,381,381,381,380,380,380,380,380,380,380,380,380,380,380,380,390,390,390,390,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,389,388,388,388,388,388,388,388,388,388,388,388,388,387,387,387,387,387,387,387,387,387,387,387,387,386,386,386,386,386,386,386,386,386,386,386,386,386,386,385,385,385,385,385,385,385,385,385,385,385,385,385,385,385,395,395,394,394,394,394,394,394,394,394,394,394,394,393,393,393,393,393,393,393,393,393,393,393,392,392,392,392,392,392,392,392,392,392,392,392,392,391,391,391,391,391,391,391,391,391,391,391,391,391,391,390,390,390,390,390,390,390,390,390,390,400,400,400,400,400,400,400,400,400,399,399,399,399,399,399,399,399,399,399,399,399,398,398,398,398,398,398,398,398,398,397,397,397,397,397,397,397,397,397,397,397,397,397,397,397,397,396,396,396,396,396,396,396,396,395,395,395,395,395,395,405,405,405,405 ...

# %% [markdown]
# You can see that the graph is skewed , because the movies which get higher rating with less no of votes are the best movies  to consider , left and top most corner movies . you can see many not-rated movies comes under this category,also , you have to understand that other certified movies are also come in this category but as we required very less number of movies and also certificate have many missing values, also not rated movies can have higher ratings so we can drop this column.

# %%
df2.drop("certificate",axis=1,inplace=True)

# %%
df3.head(1)
# Out:
#    dataId region
# 0  102795  India

# %%
df_dup1 = df3.duplicated('dataId', keep = False)
df_dup1.value_counts()
df3 = df3.drop_duplicates(subset ='dataId')

# %%
merged_df = pd.merge(df3, df1,how='inner', on='dataId')
df = pd.merge(merged_df, df2, how = 'inner', on='dataId')

# %%
df.head(1)
# Out:
#    dataId region  genre contentType          title length  releaseYear  votes  \
# 0  102795  India  Drama       movie  Ratha Kanneer    154         1954    349
#
#    rating                                        description
# 0     8.5  The story revolves around Mohanasundaram, a re...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101604 entries, 0 to 101603
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dataId       101604 non-null  int64
#  1   region       101604 non-null  object
#  2   genre        101604 non-null  object
#  3   contentType  101604 non-null  object
#  4   title        101604 non-null  object
#  5   length       101604 non-null  object
#  6   releaseYear  101604 non-null  int64
#  7   votes        101604 non-null  int64
#  8   rating       101604 non-null  float64
#  9   description  101604 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 7.8+ MB

# %%
content_type_counts = df['contentType'].value_counts()

fig = px.pie(values=content_type_counts.values, names=content_type_counts.index, title='Movie and TV Show Count')
fig.show()
# Out:
# <div>                            <div id="760b527f-1f3f-42fb-8f84-79ee8658a6ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("760b527f-1f3f-42fb-8f84-79ee8658a6ff")) {                    Plotly.newPlot(                        "760b527f-1f3f-42fb-8f84-79ee8658a6ff",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["movie","tvSeries"],"legendgroup":"","name":"","showlegend":true,"values":[72911,28693],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay ...
#
# var gd = document.getElementById('760b527f-1f3f-42fb-8f84-79ee8658a6ff');
# var x = new Muta

# %% [markdown]
# The dataset is movies biased but we will carefully observe it . We have to found that user prefer to see TV shows/ Movies.

# %%
import plotly.subplots as sp
import plotly.graph_objects as go

# Assuming df is your DataFrame
movies_df = df[df['contentType'] == 'movie']
tv_series_df = df[df['contentType'] == 'tvSeries']

# Create subplots
fig = sp.make_subplots(rows=2, cols=1, subplot_titles=['Scatter Plot for Movies', 'Scatter Plot for TV Series'],
                       shared_xaxes=True, vertical_spacing=0.1)

# Scatter plot for movies
scatter_movies = go.Scatter(x=movies_df['genre'], y=movies_df['rating'], mode='markers',
                            marker=dict(color='blue'), name='Movies')
fig.add_trace(scatter_movies, row=1, col=1)

# Scatter plot for TV series
scatter_tv_series = go.Scatter(x=tv_series_df['genre'], y=tv_series_df['rating'], mode='markers',
                               marker=dict(color='green'), name='TV Series')
fig.add_trace(scatter_tv_series, row=2, col=1)

# Update layout
fig.update_layout(title_text='Scatter Plots of Rating vs. Genre for Movies and TV Series',
                  xaxis_title='Genre', yaxis_title='Rating')

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="ba610ebd-0e06-4099-b8c2-0dd2a88d611d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba610ebd-0e06-4099-b8c2-0dd2a88d611d")) {                    Plotly.newPlot(                        "ba610ebd-0e06-4099-b8c2-0dd2a88d611d",                        [{"marker":{"color":"blue"},"mode":"markers","name":"Movies","x":["Drama","Documentary","Documentary","Horror","Drama","Biography","Action","Drama","Comedy","Comedy","Western","Short","Drama","Comedy","Adventure","Action","Action","Drama","Comedy","Comedy","Documentary","Crime","Documentary","Documentary","Animation","Documentary","Short","Comedy","Drama","Horror","Drama","Drama","Drama","Short","Documentary","Comedy","Comedy","Documentary","Comedy","Horror","Action","Drama","Horror","Crime","Action","Comedy","Fantasy","Comedy","Biography","Drama","Horror","Drama","Comedy","Comedy","Drama","Comedy","Horror","Animation","Comedy","Animation","Documentary","Comedy","Drama","Animation","Drama","Fantasy","Documentary","Comedy","Family","Comedy","Documentary","Short","Comedy","Comedy","Documentary","Drama","Documentary","Drama","Drama","Drama","Comedy","Short","Animation","Adventure","Short","Comedy","Documentary","Animation","Documentary","Comedy","Action","Drama","Drama","Drama","Drama","Comedy","Comedy","Adventure","Crime","Documentary","Comedy","Western","Animation","Family","Comedy","Drama","Horror","Drama","War","Drama","Horror","Crime","Comedy","Drama","Drama","Drama","Drama","Mystery","Action","Comedy","Crime","Drama","Adventure","Documentary","Drama","Comedy","Biography","Fantasy","Horror","Horror","Drama","Adventure","Documentary","Horror","Comedy","Drama","Comedy","Documentary","Biography","Drama","Horror","Drama","Comedy","Drama","Drama","Comedy","Drama","Thriller","Drama","Drama","Comedy","Documentary","Comedy","Drama","Documentary","Documentary","Comedy","Documentary","Family","Drama","Mystery","Drama","Drama","Sci-Fi","Action","Drama","Drama","Comedy","Drama","Comedy","Comedy","Comedy","Action","Action","Drama","Comedy","Drama","Drama","Comedy","History","Drama","Action","Comedy","Short","Comedy","Adventure","Musical","Documentary","Documentary","Action","Action","Comedy","Comedy","Family","Action","Crime","Drama","Documentary","Short","Documentary","Animation","Action","Short","Comedy","Animation","Documentary","Action","Short","Documentary","Action","Comedy","Short","Comedy","Comedy","Thriller","Romance","Comedy","Drama","Drama","Drama","Horror","Short","Drama","Romance","Comedy","Comedy","Action","Comedy","Comedy","Biography","Comedy","Mystery","Crime","Crime","Animation","Action","Horror","Crime","Adventure","Drama","Biography","Adventure","Adventure","Crime","Documentary","Drama","Drama","Comedy","Thriller","Crime","Short","Crime","Drama","Adventure","Drama","Crime","Action","Comedy","Adventure","Drama","Comedy","Animation","Action","Action","Thriller","Drama","Romance","Comedy","Comedy","Comedy","Documentary","Action","Horror","Action","Action","Thriller","Crime","Comedy","Drama","Comedy","Drama","Western","Documentary","Drama","Drama","Thriller","Comedy","Western","Drama","Short","Horror","Horror","Horror","Horror","Comedy","Short","Comedy","Comedy","Crime","Drama","Action","Comedy","Horror","Crime","Thriller","Action","Crime","Drama","Documentary","Action","Action","Documentary","Animation","Drama","Adventure","Drama","Drama","Documentary","Drama","Drama","Drama","Drama","Documentary","Comedy","Horror","Drama","Family","Drama","Animation","Comedy","Horror","Comedy","Comedy","Family","Comedy","Short","Comedy","Short","Comedy","Comedy","Drama","Documentary","Action","Animation","Drama","Drama","Comedy","Action","Action","Drama","Horror","Crime","Documentary","Comedy","Drama","Action","Drama", ...

# %% [markdown]
# drama, comedy, documentary, animation, action, biography, sport, horror, adventure, thriller, crime these are the genres where the ratings are greate than 8 and which includes both tvseries and movies.

# %%
# Assuming df is your DataFrame
fig = px.scatter(df, x='length', y='rating', color='contentType',
                 title='Scatter Plot of Length vs. Rating (Color-coded by Content Type)',
                 labels={'length': 'Length', 'rating': 'Rating', 'contentType': 'Content Type'})

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="af5dedba-ddfe-4c38-ba96-dffc39ce4bd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af5dedba-ddfe-4c38-ba96-dffc39ce4bd7")) {                    Plotly.newPlot(                        "af5dedba-ddfe-4c38-ba96-dffc39ce4bd7",                        [{"hovertemplate":"Content Type=movie\u003cbr\u003eLength=%{x}\u003cbr\u003eRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"movie","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"movie","showlegend":true,"x":[154.0,89.0,54.0,71.0,80.0,146.0,105.0,116.0,100.0,87.0,80.0,13.0,60.0,96.0,84.0,117.0,126.0,90.0,94.0,87.0,84.0,101.0,70.0,50.0,95.0,109.0,20.0,92.0,122.0,98.0,94.0,157.0,92.0,9.0,45.0,92.0,86.0,72.0,117.0,101.0,101.0,85.0,95.0,97.0,84.0,90.0,154.0,100.0,110.0,96.0,75.0,85.0,158.0,86.0,105.0,90.0,7.0,7.0,90.0,10.0,68.0,113.0,120.0,7.0,61.0,90.0,83.0,82.0,7.0,93.0,80.0,17.0,90.0,109.0,50.0,82.0,59.0,91.0,100.0,141.0,115.0,1.0,7.0,86.0,1.0,91.0,4.0,6.0,85.0,110.0,102.0,112.0,84.0,93.0,95.0,100.0,80.0,76.0,112.0,136.0,100.0,78.0,16.0,142.0,126.0,110.0,112.0,74.0,135.0,102.0,88.0,92.0,90.0,90.0,83.0,87.0,75.0,72.0,99.0,105.0,85.0,113.0,105.0,52.0,102.0,94.0,90.0,91.0,97.0,117.0,80.0,110.0,60.0,85.0,108.0,94.0,101.0,90.0,107.0,95.0,93.0,85.0,95.0,118.0,84.0,91.0,94.0,121.0,96.0,96.0,98.0,104.0,73.0,117.0,77.0,220.0,98.0,107.0,90.0,100.0,113.0,88.0,120.0,92.0,92.0,90.0,146.0,75.0,157.0,93.0,98.0,91.0,64.0,79.0,90.0,110.0,117.0,91.0,95.0,105.0,93.0,77.0,87.0,12.0,90.0,65.0,91.0,39.0,44.0,126.0,119.0,90.0,105.0,6.0,-1.0,101.0,84.0,73.0,22.0,80.0,8.0,97.0,20.0,75.0,7.0,82.0,100.0,5.0,1.0,87.0,96.0,3.0,88.0,98.0,76.0,100.0,81.0,84.0,90.0,84.0,80.0,24.0,125.0,85.0,101.0,88.0,99.0,101.0,127.0,80.0,101.0,91.0,113.0,89.0,8.0,77.0,89.0,120.0,115.0,91.0,105.0,81.0,92.0,96.0,90.0,98.0,131.0,106.0,84.0,88.0,12.0,88.0,98.0,89.0,93.0,82.0,86.0,142.0,86.0,92.0,127.0,113.0,78.0,95.0,111.0,93.0,107.0,96.0,86.0,95.0,100.0,73.0,93.0,94.0,85.0,-1.0,63.0,100.0,98.0,74.0,90.0,110.0,47.0,82.0,121.0,80.0,94.0,88.0,-1.0,35.0,85.0,77.0,95.0,81.0,82.0,14.0,90.0,100.0,90.0,132.0,128.0,97.0,70.0,90.0,84.0,86.0,94.0,105.0,71.0,86.0,100.0,91.0,8.0,117.0,90.0,133.0,93.0,77.0,101.0,104.0,121.0,-1.0,90.0,85.0,89.0,98.0,95.0,100.0,8.0,17.0,90.0,85.0,95.0,8.0,129.0,15.0,64.0,8.0,74.0,74.0,101.0,71.0,114.0,75.0,85.0,127.0,93.0,104.0,88.0,107.0,109.0,100.0,101.0,94.0,84.0,95.0,94.0,96.0,92.0,96.0,118.0,100.0,76.0,95.0,94.0,113.0,52.0,31.0,91.0,91.0,75.0,87.0,90.0,85.0,-1.0,95.0,86.0,95.0,85.0,126.0,-1.0,96.0,88.0,100.0,107.0,88.0,102.0,91.0,84.0,7.0,90.0,88.0,17.0,89.0,20.0,105.0,84.0,15.0,175.0,84.0,100.0,87.0,90.0,74.0,8.0,192.0,15.0,49.0,142.0,106.0,7.0,20.0,142.0,93.0,96.0,100.0,96.0,5.0,105.0,97.0,96.0,70.0,97.0,81.0,103.0,59.0,82.0,43.0,54.0,96.0,105.0,6.0,89.0,105.0,95.0,52.0,98.0,66.0,19.0,89.0,45.0,120.0,90.0,90.0,105.0,1.0,20.0,100.0,6.0,13.0,101.0,100.0,76.0,95.0,85.0,110.0,80.0,107.0,90.0,106.0,88.0,93.0,113.0,104.0,90.0,89.0,118.0,99.0,103.0,71.0,97.0,101.0,136.0,89.0,79.0,102.0,-1.0,86.0,98.0,96.0,87.0,85.0,90.0,142.0,85.0,99.0,85.0,95.0,81.0,94.0,-1.0,121.0,101.0,20.0,86.0,95.0,100.0,96.0,140.0,110.0,138.0,110.0,76.0,132.0,100.0,99.0,90.0,45.0,87.0,96.0,113.0,83.0,91.0,120.0,90.0,30.0,86.0,100.0,68.0,81.0,95.0,94.0,85.0,97.0,74.0,90.0,96.0,94.0,81.0,102.0,85.0,90.0,98.0,75.0,92.0,92.0,105.0,125.0,80.0,119.0,91.0,89.0,82.0,95.0,87.0,90.0,96.0,91.0,86.0,126.0,45.0,110.0,88.0,180.0,120.0,102.0,90.0,79.0,90.0,111.0,128.0,106.0,72.0,55.0,98.0,102.0,18.0,95.0,141.0,96.0,-1.0,85.0,15.0,83.0,87.0,7.0,93.0,84.0,63.0,114.0,9.0,93.0,4.0,91.0,78.0,59.0,88.0,121.0,90.0,104.0,113.0,109.0,90.0,105.0,99.0,87.0,83.0,104.0,150.0,90.0,96.0,88.0,84.0,88.0,103.0,188.0,83.0,100.0,45.0,120.0,85.0,98.0,100.0,61 ...

# %% [markdown]
# most of the values are within 570 who are higher rating shows , so I am going to drop those rows which are greater than 600. Definitely audience wants to see the conclusion of theshows in shorter period of time. I am also use only those movies who has rating above 8.0

# %%
df['length'] = pd.to_numeric(df['length'], errors='coerce')
df_filtered = df[(df['length'] <= 600) & (df['rating'] >= 8)]

# %%
df_filtered
# Out:
#         dataId          region        genre contentType  \
# 0       102795           India        Drama       movie
# 25      102820      Yugoslavia  Documentary       movie
# 59      102854  United Kingdom    Animation       movie
# 71      102866   United States        Short       movie
# 74      102869  United Kingdom  Documentary       movie
# ...        ...             ...          ...         ...
# 101594     491   United States        Drama    tvSeries
# 101595     492   United States       Comedy    tvSeries
# 101596     493   United States        Crime    tvSeries
# 101601     498   United States       Action    tvSeries
# 101602     499  United Kingdom       Comedy    tvSeries
#
#                            title  length  releaseYear   votes  rating  \
# 0                  Ratha Kanneer   154.0         1954     349     8.5
# 25             Svet Koji Nestaje   109.0         1987     349     9.5
# 59                Internet Story    10.0         2010     349     8.1
# 71                      And Then    17.0         2021     349     9.5
# 74          Demetri Martin: If I    50.0           -1     349     8.0
# ...                          ...     ...          ...     ...     ...
# 101594          The Morning Show    60.0         2019  106546     8.2
# 101595  Married... with Children    22.0         1987  106243     8.1
# 101596             Sharp Objects   421.0         2018  105484     8.1
# 101601                 Justified    44.0         2010  103427     8.6
# 101602                   Misfits    60.0         2009  103121     8.2
#
#                                               description
# 0       The story revolves around Mohanasundaram, a re...
# 25      It is a love story. When the twelve-breasted b...
# 59      A fast-paced and thought-provoking film told t...
# 71      Mana, a Japanese-American woman who arrives in...
# 74      Demetri Martin presents his existential dread ...
# ...                                                   ...
# 101594  An inside look at the lives of the people who ...
# 101595  Al is the quintessential working class dad. Pe...
# 101596  A reporter confronts the psychological demons ...
# 101601  U.S. Marshal Raylan Givens is reassigned from ...
# 101602  A group of young offenders doing community ser...
#
# [8528 rows x 10 columns]

# %%
region_df =df.groupby(['region','contentType'], as_index = False)['dataId'].count().sort_values('dataId', ascending = False)
region_df = region_df[(region_df['dataId'] >= 100) & (region_df['region'] != 'n')]

fig , (ax1, ax2) = plt.subplots(1,2)

# Left graph
sns.barplot(x = 'dataId', y = 'region', data = region_df[region_df['contentType']=='movie'], ax = ax1)
ax1.set_xlabel('Movies')
ax1.set_ylabel('Region')
ax1.set_title('Movies by Region', fontsize = 10)
ax1.tick_params(axis='y', labelsize=8)

# Right graph
sns.barplot(x = 'dataId', y = 'region', data = region_df[region_df['contentType']=='tvSeries'], ax = ax2)
ax2.set_xlabel('TV Series')
ax2.set_ylabel('')
ax2.set_title('TV Series by Region', fontsize = 10)
ax2.tick_params(axis='y', labelsize=8)

plt.subplots_adjust(wspace=0.35);

# %% [markdown]
# Here definitely say that UsA, Uk, Japan, Canada, India movies are most rated , you can say that population is one of the factors but UK has 20 times less population than India , though it has high ratings. So I am going to extract top 5 regional movies.

# %%
regions_of_interest = ["India", "United States", "United Kingdom", "Japan", "Canada"]
df_filtered1 = df_filtered[df_filtered["region"].isin(regions_of_interest)]

# %%
df_filtered1
# Out:
#         dataId          region        genre contentType  \
# 0       102795           India        Drama       movie
# 59      102854  United Kingdom    Animation       movie
# 71      102866   United States        Short       movie
# 74      102869  United Kingdom  Documentary       movie
# 102     102897           Japan    Animation       movie
# ...        ...             ...          ...         ...
# 101594     491   United States        Drama    tvSeries
# 101595     492   United States       Comedy    tvSeries
# 101596     493   United States        Crime    tvSeries
# 101601     498   United States       Action    tvSeries
# 101602     499  United Kingdom       Comedy    tvSeries
#
#                            title  length  releaseYear   votes  rating  \
# 0                  Ratha Kanneer   154.0         1954     349     8.5
# 59                Internet Story    10.0         2010     349     8.1
# 71                      And Then    17.0         2021     349     9.5
# 74          Demetri Martin: If I    50.0           -1     349     8.0
# 102      The Day I Bought a Star    16.0         2006     348     8.2
# ...                          ...     ...          ...     ...     ...
# 101594          The Morning Show    60.0         2019  106546     8.2
# 101595  Married... with Children    22.0         1987  106243     8.1
# 101596             Sharp Objects   421.0         2018  105484     8.1
# 101601                 Justified    44.0         2010  103427     8.6
# 101602                   Misfits    60.0         2009  103121     8.2
#
#                                               description
# 0       The story revolves around Mohanasundaram, a re...
# 59      A fast-paced and thought-provoking film told t...
# 71      Mana, a Japanese-American woman who arrives in...
# 74      Demetri Martin presents his existential dread ...
# 102     A young boy is tired of the city and escapes i...
# ...                                                   ...
# 101594  An inside look at the lives of the people who ...
# 101595  Al is the quintessential working class dad. Pe...
# 101596  A reporter confronts the psychological demons ...
# 101601  U.S. Marshal Raylan Givens is reassigned from ...
# 101602  A group of young offenders doing community ser...
#
# [5699 rows x 10 columns]

# %% [markdown]
# drama, comedy, documentary, animation, action, biography, sport, horror, adventure, thriller, crime

# %% [markdown]
# This is our final dataset ,now We already have 6 moods sad, angry , joy, happy, brave and lazy
# It is impossible to make a choice of movies for a specific mood based user, so I am going to use a following mapping :
# 1. drama, comedy
# 2. drama, documentary, sport, biography, animation
# 3. drama, horror, action
# 4. comedy, thriller, sport
# 5. sport, drama, comedy, animation, adventure, action
# 6. thriller, crime, sport,horror

# %% [markdown]
# Lets map the dataset,

# %%
df0=df_filtered1[df_filtered[""]]
# Out:
# /tmp/ipykernel_42/801888648.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create separate DataFrames based on genres
df0 = df_filtered1[df_filtered1['genre'].str.contains('Drama') | df_filtered1['genre'].str.contains('Comedy')]
df1 = df_filtered1[df_filtered1['genre'].str.contains('Drama') | df_filtered1['genre'].str.contains('Documentary') | df_filtered1['genre'].str.contains('Sport') | df_filtered1['genre'].str.contains('Biography') | df_filtered1['genre'].str.contains('Animation')]
df2 = df_filtered1[df_filtered1['genre'].str.contains('Drama') | df_filtered1['genre'].str.contains('Horror') | df_filtered1['genre'].str.contains('Action')]
df3 = df_filtered1[df_filtered1['genre'].str.contains('Comedy') | df_filtered1['genre'].str.contains('Thriller') | df_filtered1['genre'].str.contains('Sport')]
df4 = df_filtered1[df_filtered1['genre'].str.contains('Sport') | df_filtered1['genre'].str.contains('Drama') | df_filtered1['genre'].str.contains('Comedy') | df_filtered1['genre'].str.contains('Animation') | df_filtered1['genre'].str.contains('Adventure') | df_filtered1['genre'].str.contains('Action')]
df5 = df_filtered1[df_filtered1['genre'].str.contains('Thriller') | df_filtered1['genre'].str.contains('Crime') | df_filtered1['genre'].str.contains('Sport') | df_filtered1['genre'].str.contains('Horror')]

# %%
print(df0.shape)
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
# Out:
# (1936, 10)
# (3153, 10)
# (1198, 10)
# (1165, 10)
# (3102, 10)
# (352, 10)

# %%
def recommend_movies(value):
    # Define mini-datasets based on genres
    mini_datasets = {
        0: df0,
        1: df1,
        2: df2,
        3: df3,
        4: df4,
        5: df5
    }

    # Check if the provided value is valid
    if value not in mini_datasets:
        return "Invalid input. Please provide a value between 0 and 5."

    # Recommend the top 10 movies based on IMDb ratings for the corresponding mini-dataset
    top_movies = mini_datasets[value].nlargest(10, 'rating')[['title', 'rating']]
    return top_movies

# Example usage:
recommended_movies = recommend_movies(0)
print(recommended_movies)
# Out:
#                           title  rating
# 55893               Shubh Nikah    10.0
# 59699  Steven Reeds Weber Cooks     9.9
# 24588               Nee Jathaga     9.8
# 36286           Richiegadipelli     9.8
# 44606            Mrwhosetheboss     9.8
# 61701                  Couchers     9.8
# 56904                 Train Guy     9.7
# 33987             Dooradarshana     9.6
# 49189      We Are with the Band     9.6
# 51941                 SuperMega     9.6
